# %%
# %store -r dt_unzeroed

# %%
dt_unzeroed
# Out:
#          CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_COR_RACA  \
# 3                      17               TO      25.0       F            1
# 4                      31               MG      22.0       F            1
# 5                      51               MT      37.0       M            2
# 6                      29               BA      22.0       F            3
# 9                      35               SP      17.0       M            1
# ...                   ...              ...       ...     ...          ...
# 5095257                51               MT      20.0       M            1
# 5095259                22               PI      37.0       F            4
# 5095260                35               SP      17.0       F            1
# 5095263                15               PA      33.0       F            3
# 5095264                35               SP      17.0       F            3
#
#          TP_ESCOLA  IN_TREINEIRO  TP_PRESENCA_CN  TP_PRESENCA_CH  \
# ...

# %%
notas= ['NU_NOTA_CN', 'NU_NOTA_MT', 'NU_NOTA_LC', 'NU_NOTA_CH', 'NU_NOTA_REDACAO']
dt_unzeroed[notas].dropna().describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#           NU_NOTA_CN     NU_NOTA_MT     NU_NOTA_LC     NU_NOTA_CH  \
# count  3596117.00000  3596117.00000  3596117.00000  3596117.00000
# mean       479.43889      525.27941      524.32489      511.99338
# std         76.01345      109.24598       61.64076       80.28143
# min          0.00000        0.00000        0.00000        0.00000
# 25%        419.40000      436.90000      488.10000      453.70000
# 50%        472.40000      503.90000      529.40000      515.70000
# 75%        534.90000      600.60000      567.70000      570.10000
# max        860.90000      985.50000      801.70000      835.10000
#
#       NU_NOTA_REDACAO
# count   3596117.00000
# mean        596.84109
# std         155.24903
# min          40.00000
# 25%         500.00000
# 50%         580.00000
# 75%         680.00000
# max        1000.00000

# %%
# Arithmetic mean (“average”) of data.
dt_unzeroed['NU_NOTA_REDACAO'].mean()
# Out:
# 596.8410927675601

# %%
# Compute the median along the specified axis.
dt_unzeroed['NU_NOTA_REDACAO'].median()
# Out:
# 580.0

# %%
# Single mode (most common value) of discrete or nominal data.
dt_unzeroed['NU_NOTA_REDACAO'].mode()
# Out:
# 0    600.0
# Name: NU_NOTA_REDACAO, dtype: float64

# %%
# Returns the standard deviation, a measure of the spread of a distribution, of the array elements.
dt_unzeroed['NU_NOTA_REDACAO'].std()
# Out:
# 155.24903205195363
